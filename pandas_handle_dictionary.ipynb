# %%
import pandas as pd
import json
import ast #handle single/double quote in dict/json string
import sys

# %%
print(pd.Timestamp.now())
# Out:
# 2023-11-15 04:01:10.645518

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/dict_list_column.tsv', sep='\t')
df
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']

# %%
type(df['price'][0])
# Out:
# str

# %%
for c in df.columns:
  print(f'{c:10}:{type(df[c][0])} {df[c][0]}')
# Out:
# menu      :<class 'str'> mocha
# price     :<class 'str'> {"S":40, "M":50, "L":60}
# price2    :<class 'str'> {'S':40, 'M':50, 'L':60}
# orders    :<class 'str'> 70,10,100
# orders2   :<class 'str'> [70,10,100]
# serve     :<class 'str'> hot,cold,frappe
# serve2    :<class 'str'> ['hot', 'cold', 'frappe']

# %%
j=json.loads('{"S":40,"M":50,"L":60}')
print(type(j))
print(j)
# Out:
# <class 'dict'>
# {'S': 40, 'M': 50, 'L': 60}

# %%
j['M']
# Out:
# 50

# %%
df['price_j']=df['price'].map(json.loads)

# %%
df
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2  \
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']
#
#                        price_j
# 0  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}

# %%
df['price_k']=df['price'].apply(lambda s:json.loads(s))
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2  \
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']
#
#                        price_j                      price_k
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}

# %%
json.loads("{'S':40,'M':50,'L':60}") #Error เพราะไม่ได้อยู่ใน Format Json ที่ต้องเป็น Double quote เท่านั้น
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-18-8b8c65be9d4f> in <cell line: 1>()
# ----> 1 json.loads("{'S':40,'M':50,'L':60}")
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
x=ast.literal_eval('{"S":40,"M":50,"L":60}')
print(type(x))
print(x)
# Out:
# <class 'dict'>
# {'S': 40, 'M': 50, 'L': 60}

# %%
k=ast.literal_eval("{'S':40,'M':50,'L':60}")
print(type(k))
print(k)
# Out:
# <class 'dict'>
# {'S': 40, 'M': 50, 'L': 60}

# %%
df['price_j2']=df['price2'].map(ast.literal_eval)
df
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2  \
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']
#
#                        price_j                      price_k  \
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}
#
#                       price_j2
# 0  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}

# %%
df['price_k2']=df['price'].apply(lambda s:ast.literal_eval(s))
df
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2  \
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']
#
#                        price_j                      price_k  \
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}
#
#                       price_j2                     price_k2
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}

# %%
df['price_j']
# Out:
# 0    {'S': 40, 'M': 50, 'L': 60}
# 1    {'S': 45, 'M': 60, 'L': 70}
# 2    {'S': 39, 'M': 49, 'L': 59}
# Name: price_j, dtype: object

# %%
df['price_j'][1]
# Out:
# {'S': 45, 'M': 60, 'L': 70}

# %%
df.loc[1,'price_j']
# Out:
# {'S': 45, 'M': 60, 'L': 70}

# %%
df['price_j'][1]['S']
# Out:
# 45

# %%
df['price_j'][1]['M']
# Out:
# 60

# %%
df['price_j'].apply(lambda v:v['M'])
# Out:
# 0    50
# 1    60
# 2    49
# Name: price_j, dtype: int64

# %%
df['price_medium']=df['price_j'].apply(lambda v:v['M'])
df
# Out:
#        menu                     price                    price2     orders  \
# 0     mocha  {"S":40, "M":50, "L":60}  {'S':40, 'M':50, 'L':60}  70,10,100
# 1     latte  {"S":45, "M":60, "L":70}  {'S':45, 'M':60, 'L':70}   40,20,80
# 2  espresso  {"S":39, "M":49, "L":59}  {'S':39, 'M':49, 'L':59}   120,5,50
#
#        orders2            serve                     serve2  \
# 0  [70,10,100]  hot,cold,frappe  ['hot', 'cold', 'frappe']
# 1   [40,20,80]         hot,cold            ['hot', 'cold']
# 2   [120,5,50]              hot                    ['hot']
#
#                        price_j                      price_k  \
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}
#
#                       price_j2                     price_k2  price_medium
# 0  {'S': 40, 'M': 50, 'L': 60}  {'S': 40, 'M': 50, 'L': 60}            50
# 1  {'S': 45, 'M': 60, 'L': 70}  {'S': 45, 'M': 60, 'L': 70}            60
# 2  {'S': 39, 'M': 49, 'L': 59}  {'S': 39, 'M': 49, 'L': 59}            49
