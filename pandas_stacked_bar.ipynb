# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 1.5.3

# %%
pd.set_option('display.max_rows',10)

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/pisa2015.csv')
df
# Out:
#                Country  Maths  Science  Reading
# 0            Singapore    564      556      535
# 1            Hong Kong    548      523      527
# 2                Macau    544      529      509
# 3               Taiwan    542      532      497
# 4                Japan    532      538      516
# ..                 ...    ...      ...      ...
# 65           Macedonia    371      384      352
# 66             Tunisia    367      386      361
# 67              Kosovo    362      378      347
# 68             Algeria    360      376      350
# 69  Dominican Republic    328      332      358
#
# [70 rows x 4 columns]

# %%
df[:5].plot(kind='bar',stacked=True)
# Out:
# <Axes: >

# %%
df.set_index('Country', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-9d6dff73bdc7> in <cell line: 1>()
# ----> 1 df.set_index('Country', inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
df
# Out:
#                     Maths  Science  Reading
# Country
# Singapore             564      556      535
# Hong Kong             548      523      527
# Macau                 544      529      509
# Taiwan                542      532      497
# Japan                 532      538      516
# ...                   ...      ...      ...
# Macedonia             371      384      352
# Tunisia               367      386      361
# Kosovo                362      378      347
# Algeria               360      376      350
# Dominican Republic    328      332      358
#
# [70 rows x 3 columns]

# %%
df[:5].plot(kind='bar',stacked=True,title='Pisa score 2015');

# %%
df=pd.read_csv('https://github.com/prasertcbs/basic-dataset/raw/master/pisa2015.csv',index_col='Country')

# %%
df
# Out:
#                     Maths  Science  Reading
# Country
# Singapore             564      556      535
# Hong Kong             548      523      527
# Macau                 544      529      509
# Taiwan                542      532      497
# Japan                 532      538      516
# ...                   ...      ...      ...
# Macedonia             371      384      352
# Tunisia               367      386      361
# Kosovo                362      378      347
# Algeria               360      376      350
# Dominican Republic    328      332      358
#
# [70 rows x 3 columns]

# %%
df[:5].plot(kind='barh',stacked=True,title='Pisa score 2015');

# %%
df[:5].plot(kind='barh',stacked=True,title='Pisa score 2015',figsize=(8,4));

# %%
ax=df[:5][['Maths','Science']].plot(kind='barh',stacked=True,color=['gold','c'],
                                    title='Pisa Score 2015');
ax.set_xlabel('Score')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
df['Total'] = df.Maths+df.Science+df.Reading
df
# Out:
#                     Maths  Science  Reading  Total
# Country
# Singapore             564      556      535   1655
# Hong Kong             548      523      527   1598
# Macau                 544      529      509   1582
# Taiwan                542      532      497   1571
# Japan                 532      538      516   1586
# ...                   ...      ...      ...    ...
# Macedonia             371      384      352   1107
# Tunisia               367      386      361   1114
# Kosovo                362      378      347   1087
# Algeria               360      376      350   1086
# Dominican Republic    328      332      358   1018
#
# [70 rows x 4 columns]

# %%
df.nlargest(10,'Total')[['Maths','Science','Reading']].plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='Country'>

# %%
df.loc[['Japan','Taiwan','Vietnam','Thailand'],['Maths','Science','Reading']].plot(kind='barh',stacked=True)
# Out:
# <Axes: ylabel='Country'>

# %%
ax=df.loc[['Japan','Taiwan','Vietnam','Thailand'],['Maths','Science','Reading']].plot(kind='barh',stacked=True)
ax.xaxis.set_major_formatter(FuncFormatter(lambda v,p:"{:,.0f}".format(v))) #set comma delemiter
ax.set_xlabel('Score')
ax.set_ylabel('');
