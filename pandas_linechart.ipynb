# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
pd.set_option('display.max_rows',10)

# %%
oil = pd.read_csvb
oil
# Out:
#               Oil
# Date
# 2003-01-31  30.71
# 2003-02-28  32.63
# 2003-03-31  27.22
# 2003-04-30  23.72
# 2003-05-31  26.71
# ...           ...
# 2018-02-28  63.97
# 2018-03-31  65.87
# 2018-04-30  71.01
# 2018-05-31  75.17
# 2018-06-30  74.23
#
# [186 rows x 1 columns]

# %%
oil.plot(kind='line');

# %%
ax = oil.plot(kind='line',title = 'OPEC oil price')
ax.set_xlabel('')
ax.set_ylabel('US/barrel');

# %%
ax = oil.plot(kind='line',title = 'OPEC oil price',color='salmon')
ax.set_xlabel('')
ax.set_ylabel('US/barrel');

# %%
ax = oil.plot(kind='line',title = 'OPEC oil price',color='salmon')
ax.set_xlabel('')
ax.set_ylabel('US/barrel')
ax.axhline(oil['Oil'].mean(),color='black',linestyle="--",linewidth=.8);
