# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
df = pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(10)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 189       toyota        camry solara    2.4  2008    4    auto(s5)   f   22
# 153       nissan      pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 58         dodge         durango 4wd    4.7  2008    8    auto(l5)   4   13
# 14          audi          a4 quattro    3.1  2008    6  manual(m6)   4   15
# 25     chevrolet            corvette    6.2  2008    8  manual(m6)   r   16
# 169       subaru         impreza awd    2.5  2008    4    auto(s4)   4   20
# 208   volkswagen                 gti    2.0  1999    4    auto(l4)   f   19
# 75          ford      expedition 2wd    5.4  1999    8    auto(l4)   r   11
# 126         jeep  grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
# 45         dodge         caravan 2wd    3.8  1999    6    auto(l4)   f   15
#
#      hwy fl    class
# 189   31  r  compact
# 153   18  p      suv
# 58    17  r      suv
# 14    25  p  compact
# 25    26  p  2seater
# 169   25  p  compact
# 208   26  r  compact
# 75    17  r      suv
# 126   12  e      suv
# 45    21  r  minivan

# %%
df.boxplot();

# %%
df.boxplot(figsize=(10,4))
# Out:
# <Axes: >

# %%
df.boxplot(column=['displ','cyl'],figsize=(10,4))
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
for column in ['displ','cyl','cty','hwy']:
  df.boxplot(column)
  plt.show()

# %%
fig, ax=plt.subplots(1,4,figsize=(10,4))
columns=['displ','cyl','cty','hwy']
for i,column in enumerate(columns):
  df.boxplot(column,ax=ax[i])

# %%
columns=['displ','cyl','cty','hwy']
nrows=2
ncols=math.ceil(len(column)/nrows)
fig,ax = plt.subplots(nrows,ncols,figsize=(ncols*3,nrows*4))
print(ax.shape)
col_idx=0
if nrows==1 or ncols==1:
  for c in range(ax.size):
    if col_idx < len(column):
      df.boxplot(columns[col_idx],ax=ax[c])
      col_idx+=1
else:
  for r in range(nrows):
    for c in range(ncols):
      if col_idx < len(columns):
        df.boxplot(columns[col_idx],ax=ax[r,c])
        col_idx+=1
# Out:
# (2, 2)

# %%
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
df.columns.str.match('year')
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#        False, False])

# %%
df.columns[~df.columns.str.match('year')]
# Out:
# Index(['manufacturer', 'model', 'displ', 'cyl', 'trans', 'drv', 'cty', 'hwy',
#        'fl', 'class'],
#       dtype='object')

# %%
df.select_dtypes('number') # select only number
# Out:
#      displ  year  cyl  cty  hwy
# 0      1.8  1999    4   18   29
# 1      1.8  1999    4   21   29
# 2      2.0  2008    4   20   31
# 3      2.0  2008    4   21   30
# 4      2.8  1999    6   16   26
# ..     ...   ...  ...  ...  ...
# 229    2.0  2008    4   19   28
# 230    2.0  2008    4   21   29
# 231    2.8  1999    6   16   26
# 232    2.8  1999    6   18   26
# 233    3.6  2008    6   17   26
#
# [234 rows x 5 columns]

# %%
df[df.columns[~df.columns.str.match('year')]].select_dtypes('number') # Exclude Column year and select only number
# Out:
#      displ  cyl  cty  hwy
# 0      1.8    4   18   29
# 1      1.8    4   21   29
# 2      2.0    4   20   31
# 3      2.0    4   21   30
# 4      2.8    6   16   26
# ..     ...  ...  ...  ...
# 229    2.0    4   19   28
# 230    2.0    4   21   29
# 231    2.8    6   16   26
# 232    2.8    6   18   26
# 233    3.6    6   17   26
#
# [234 rows x 4 columns]
